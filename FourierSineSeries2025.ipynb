# %%
import sympy as smp
import matplotlib.pyplot as plt
from sympy.plotting import plot
from sympy.plotting import plot3d

# %%
m,n = smp.symbols('m n', integer=True, postive=True)

# %%
x = smp.symbols('x')
summ =smp.Function('summ')
f =smp.Function('f')
A=smp.Function('A')
B=smp.Function('B')

# %%
f = f(x)
A=A(m)
B=B(m)

# %%
# f=x**3

# f=(smp.pi+x)*(smp.pi-x)

# f = smp.Piecewise(
#     (0, (-smp.pi < x)& (x < -1)),
#     (x+1,(-1<x)&(x<0)),(-x+1,(0<x)&(x<1)),
#     ( 0, True )
# )

# f = smp.Piecewise(
#     (0, (0 < x)& (x <= 0.25)),
#     (1,(0.25<x)&(x<=0.75)),
#     ( 0, True )
# )


# f=x*smp.sin(3*x)

# f = -x**2+(smp.pi)**2

# f = smp.Piecewise(
#     (0, (-smp.pi < x)& (x < -1)),
#     (x+1,(-1<x)&(x<0)),(-x+1,(0<x)&(x<1)),
#     ( 0, True )
# )

f = smp.Piecewise(
    (1, (-1 < x)& (x < 0)),
    (1,(0<x)&(x<1)),
    ( 0, True )
)

# %%
plot(f,show=True,xlim=[-smp.pi,smp.pi],ylim=[-2,2])

# %%
CosMdotCosM = smp.integrate(smp.cos(m*x)*smp.cos(m*x),(x,-smp.pi,smp.pi)).simplify()
# SinMdotSinM = smp.integrate(smp.sin(m*x)*smp.sin(m*x),(x,0,smp.pi)).simplify()
# SinMdotSinM = smp.integrate(smp.sin(m*x)*smp.sin(m*x),(x,-smp.pi,smp.pi)).simplify()

# %%
f
# Out:
# Piecewise((1, ((x > -1) | (x > 0)) & ((x > -1) | (x < 1)) & ((x > 0) | (x < 0)) & ((x < 0) | (x < 1))), (0, True))

# %%
CosMdotCosM
# Out:
# Piecewise((pi, (m > 0) | (m < 0)), (2*pi, True))

# %%
integrandA = f*smp.cos(m*x)/(smp.pi)

# %%
integrandA
# Out:
# Piecewise((1, ((x > -1) | (x > 0)) & ((x > -1) | (x < 1)) & ((x > 0) | (x < 0)) & ((x < 0) | (x < 1))), (0, True))*cos(m*x)/pi

# %%
A = smp.integrate(integrandA,(x,-smp.pi,smp.pi)).simplify()

# %%
A
# Out:
# Piecewise((2*sin(m)/(pi*m), (m > 0) | (m < 0)), (2/pi, True))

# %%
summ=0
A0=(1/(2*smp.pi))*smp.integrate(f,(x,-smp.pi,smp.pi)).simplify()
summ=summ+A0
# 
# empezamos con summ = A0 = (integral f) / 2PI
# cambia ylim segun la funcion
grp = plot(f,show=False,xlim=[-smp.pi,smp.pi],ylim=[-0.25,1.25])
# plot f, la funcion original
for i in range(1,50):
#     en cada paso, summ es una aproximacion de f con un termino
#     mas de cos y un termino mas de sin de la serie de Fourier
    summ = summ +A.subs(m,i)*smp.cos(i*x)
    # print(summ)
    dl = plot(summ,show=False)
    grp.extend(dl)
    # plt.plot(summ,show=True)
# Podemos ver como las aproximaciones se acercan a la funcion original
grp.show()

# %%
plot(summ,f,show=True,xlim=[-smp.pi,smp.pi],ylim=[-2,2])
